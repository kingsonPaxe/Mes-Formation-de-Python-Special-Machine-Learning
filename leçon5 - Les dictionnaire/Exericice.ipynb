# %% [markdown]
# ## **Classeur les valeurs dans la dictionaire**

# %%
classeur = {
    "positif": [],
    "negatif": []
}
classeur
# Out:
# {'positif': [], 'negatif': []}

# %%
def trier(classeur, nombre):
    
    if nombre < 0:
        classeur["negatif"].append(nombre)
    else:
        classeur["positif"].append(nombre)
        
    return classeur
# trier c'est: classeur, ordernar, organisar, serparar, etc...
nombre = int(input("informez le nombre: "))
trier(classeur,nombre)
# Out:
# informez le nombre: 0
# {'positif': [12, 234, 0], 'negatif': [-221, -123]}

# %% [markdown]
# #### EX1: Faça um programa que leia **nome e média** de um aluno, guardando também a **situação** em um **dicionario**. No final, mostre o conteudo da estrutura na tela.

# %%
nome = input("Nome: ")
media = int(input(f'Media de {nome}: '))

aluno = {
    'Nome': nome,
    'Media': media
}

print(f'Nome é igual a {aluno["Nome"]}')
print(f'Media é igual a {aluno["Media"]}v')

if media < 5:
    print('Situação é igual a Reprovado')
else:
    print('Situação é igual a Aprovado')
# Out:
# Nome: Carlos Paxe
# Media de Carlos Paxe: 4
# Nome é igual a Carlos Paxe
# Media é igual a 4v
# Situação é igual a Reprovado

# %% [markdown]
# #### EX2: Crie um programa onde **4 jogadores** joguem um **dado** e tenham resultados **aleatorios**. Guarde esses resultados em um **dicionario**.No final, coloque esse dicionario em **ordem**, sabendo que o **vencedor** tirou o **maior** **numero** no lado.

# %%
import random as rd
gamers = {}
jogadores = []

for jogadas in range(4):
    valores = rd.randint(0,6)
    jogadores.append(valores)
    
print(jogadores)

gamers['Jogador 1'] = jogadores[0]
gamers['Jogador 2'] = jogadores[1]
gamers['Jogador 3'] = jogadores[2]
gamers['Jogador 4'] = jogadores[3]
# Out:
# [2, 1, 6, 0]

# %%
print(f"""

        Jogador1 = {gamers['Jogador 1']}
        Jogador2 = {gamers['Jogador 2']}
        Jogador3 = {gamers['Jogador 3']}
        Jogador4 = {gamers['Jogador 4']}
""")
# Out:
#         Jogador1 = 6
#         Jogador2 = 6
#         Jogador3 = 4
#         Jogador4 = 0

# %%
jogadores.sort()

# %%
gamers
# Out:
# {'Jogador 1': 4, 'Jogador 2': 6, 'Jogador 3': 5, 'Jogador 4': 2}
