# %% [markdown]
# # Exercice
# Standardisez la matrice A sur chaque colonne.
# A - ~A/std(A)
#
# Resultat: chaque colonne doit avoir moyenne = 0 et écart type = 1

# %%
import numpy as np
np.random.seed(0)
A = np.random.randint(0, 100, [10, 5])
A
# Out:
# array([[44, 47, 64, 67, 67],
#        [ 9, 83, 21, 36, 87],
#        [70, 88, 88, 12, 58],
#        [65, 39, 87, 46, 88],
#        [81, 37, 25, 77, 72],
#        [ 9, 20, 80, 69, 79],
#        [47, 64, 82, 99, 88],
#        [49, 29, 19, 19, 14],
#        [39, 32, 65,  9, 57],
#        [32, 31, 74, 23, 35]])

# %%
A = A - ~A/np.std(A)
A
# Out:
# array([[ 45.70895693,  48.82288739,  66.46849334,  69.58242381,
#          69.58242381],
#        [  9.37976821,  86.19005294,  21.83549005,  37.40514236,
#          90.34196022],
#        [ 72.69635427,  91.37993704,  91.37993704,  12.49369867,
#          60.24063242],
#        [ 67.50647016,  40.51907283,  90.34196022,  47.78491057,
#          91.37993704],
#        [ 84.1140993 ,  38.44311919,  25.98739734,  79.96219201,
#          74.77230791],
#        [  9.37976821,  20.79751323,  83.07612247,  71.65837745,
#          82.03814565],
#        [ 48.82288739,  66.46849334,  85.15207612, 102.79768207,
#          91.37993704],
#        [ 50.89884103,  30.13930462,  19.75953641,  19.75953641,
#          14.56965231],
#        [ 40.51907283,  33.25323508,  67.50647016,   9.37976821,
#          59.2026556 ],
#        [ 33.25323508,  32.21525826,  76.84826155,  23.9114437 ,
#          36.36716554]])
