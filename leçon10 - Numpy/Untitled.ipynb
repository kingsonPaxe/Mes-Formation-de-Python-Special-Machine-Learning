# %% [markdown]
# # Exercices

# %%
import numpy as np
'Done.'
# Out:
# 'Done.'

# %%
p = np.random.randn(5,5)
np.ones((p.shape[1], 1))
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
def initialisation(m,n):
    X = np.random.randn(m,n)
    X = np.concatenate((X, np.ones((X.shape[0], 1))), axis = 1)
    return X

# %%
initialisation(3,4)
# Out:
# array([[-0.8822094 , -0.40574361, -1.26986371,  0.3992537 ,  1.        ],
#        [ 0.26645736, -0.76635653,  0.64390897,  0.0349765 ,  1.        ],
#        [ 0.33492816, -0.08612215, -1.98599678, -1.4314209 ,  1.        ]])
