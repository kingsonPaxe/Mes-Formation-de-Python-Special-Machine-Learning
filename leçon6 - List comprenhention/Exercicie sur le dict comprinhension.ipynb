# %% [markdown]
# # Exercice

# %% [markdown]
# criar uma dict comprihension onde
# d = k:v
#     k = 0-20
#     v = k**2

# %%
d = {k:v**2 for k,v in enumerate(range(0,21))}
d
# Out:
# {0: 0,
#  1: 1,
#  2: 4,
#  3: 9,
#  4: 16,
#  5: 25,
#  6: 36,
#  7: 49,
#  8: 64,
#  9: 81,
#  10: 100,
#  11: 121,
#  12: 144,
#  13: 169,
#  14: 196,
#  15: 225,
#  16: 256,
#  17: 289,
#  18: 324,
#  19: 361,
#  20: 400}
