# %% [markdown]
# # Revision

# %%
dit = {
    '0': 'Pierre',
    '1': 'Jean',
    '2': 'Fred'
}
dit
# Out:
# {'0': 'Pierre', '1': 'Jean', '2': 'Fred'}

# %% [markdown]
# # List Comprihension

# %%
nomes = [v for v in dit.values()]
nomes
# Out:
# ['Pierre', 'Jean', 'Fred']

# %%
print(nomes[1])
print(f"Esta lista tem {len(nomes)} elementos")
# Out:
# Jean
# Esta lista tem 3 elementos

# %% [markdown]
# # Dict compriheinsion

# %%
dt = { k:v for k,v in enumerate(nomes)}
dt
# Out:
# {0: 'Pierre', 1: 'Jean', 2: 'Fred'}

# %%
age = [idade for idade in range(20, 100, 30)] 
age
# Out:
# [20, 50, 80]

# %%
import numpy as np
age2 = np.arange(20, 100, 30)
age2
# Out:
# array([20, 50, 80])

# %%
prenoms = ['Pierre', 'Jean', 'Fred']
age = [12,23,11]

# %%
dict(enumerate(prenoms))
# Out:
# {0: 'Pierre', 1: 'Jean', 2: 'Fred'}

# %%
dict(zip(nomes,age2))
# Out:
# {'Pierre': 20, 'Jean': 50, 'Fred': 80}

# %% [markdown]
# # Exericios

# %% [markdown]
# Créer une dict comprihension où: d = k:v, k = 0-20, v**2

# %%
reponse = {k:v**2 for k,v in enumerate(range(0,20))}
reponse
# Out:
# {0: 0,
#  1: 1,
#  2: 4,
#  3: 9,
#  4: 16,
#  5: 25,
#  6: 36,
#  7: 49,
#  8: 64,
#  9: 81,
#  10: 100,
#  11: 121,
#  12: 144,
#  13: 169,
#  14: 196,
#  15: 225,
#  16: 256,
#  17: 289,
#  18: 324,
#  19: 361}

# %%
# Out:
# range(3, 10)
