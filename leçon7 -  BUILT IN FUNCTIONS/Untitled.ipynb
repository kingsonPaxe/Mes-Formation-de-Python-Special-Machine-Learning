# %% [markdown]
# # Revision

# %% [markdown]
# ## any()

# %%
bool = [True, True, False]
any(bool)
# Out:
# True

# %% [markdown]
# ## all()

# %%
bool = [True, True, False]
all(bool)
# Out:
# False

# %% [markdown]
# ## round()

# %%
pi = 3.141592653589793
print(round(pi,2))
# Out:
# 3.14

# %% [markdown]
# ## open()

# %%
with open('paxe.txt', 'w') as file:
    file.write('Bom dia Deus!')

# %%
with open('paxe.txt', 'r') as file:
    print(file.read())
# Out:
# Bom dia Deus!

# %% [markdown]
# ## Exercicies

# %%
reponse = [f"{x}^2 = {x**2}" for x in range(0, 10) ]
reponse
# Out:
# ['0^2 = 0',
#  '1^2 = 1',
#  '2^2 = 4',
#  '3^2 = 9',
#  '4^2 = 16',
#  '5^2 = 25',
#  '6^2 = 36',
#  '7^2 = 49',
#  '8^2 = 64',
#  '9^2 = 81']

# %%
with open('paxe.txt','w') as file:
    file.write(str(reponse))

# %%
with open('paxe.txt','r') as file:
    print(file.read())
# Out:
# ['0^2 = 0', '1^2 = 1', '2^2 = 4', '3^2 = 9', '4^2 = 16', '5^2 = 25', '6^2 = 36', '7^2 = 49', '8^2 = 64', '9^2 = 81']
