# %% [markdown]
# # Exercicies
#
# Lire 'ficher.txt' et retourner une list [' 0^2 = 0', ' 1^2 = 1', ..., ' 9^2 = 81']

# %%
v = list()
with open('ficher.txt','w') as f:
    for valeur in range(0, 10):
        v.append(f' {valeur}^2 = {valeur ** 2}')
    res =  f.write(str(v))

# %%
print('teste')
# Out:
# teste
