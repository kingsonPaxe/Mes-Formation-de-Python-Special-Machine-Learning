# %%
list1 = [12,34,45,11]
sum(list1)
# Out:
# 102

# %%
valor_int = 1
bin(valor_int)[2:]
# Out:
# '1'

# %%
print(sorted(list1))
# Out:
# [11, 12, 34, 45]

# %%
list2 = [12, 3, -44, 2, 11]
list2
# Out:
# [12, 3, -44, 2, 11]

# %%
list2
# Out:
# [-44, 2, 3, 11, 12]

# %%
list_bool = [False, False, True]
any(list_bool)
# Out:
# True

# %%
db1 = {
    "Nome": ["Pedro"],
    "Idade": [32],
    "Nacionalidade":["Angolana "],
}

db2 = {
    "Função": ["Estudande"],
    "Email": ["Exemplo@gmail.com"],
}


print(db1,"\n",db2)
# Out:
# {'Nome': ['Pedro'], 'Idade': [32], 'Nacionalidade': ['Angolana ']}
#  {'Função': ['Estudande'], 'Email': ['Exemplo@gmail.com']}

# %%
import pandas as pd
df = pd.DataFrame(db1)
df
# Out:
#     Nome  Idade Nacionalidade
# 0  Pedro     32     Angolana

# %%
valor =  3.14159
print(round(valor,2))
# Out:
# 3.14

# %%
numeros = [1, 2, 3, 4, 5, 6]
result = [val for val in numeros if val%2 == 0]
result
# Out:
# [2, 4, 6]

# %%
numeros = [1, 2, 3, 4, 5, 6]
def result(v):
    if v%2 == 0:
        return v**2
val = map(result, numeros)
val = list(val)
val
# Out:
# [1, 4, 9, 16, 25, 36]
